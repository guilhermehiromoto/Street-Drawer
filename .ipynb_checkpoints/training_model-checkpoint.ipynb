# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import keras
import random

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## For this project we are using a model-based methodology for Image Segmentation

# %% [markdown]
# ### A metrica que utilizaremos pra treinar o nosso modelo eh a Intersection-Over-Union
#
# Essa metrica consiste em calcular a area de sobreposição entre a segmentação prevista e a mascara dividido pela area de união entre a segmentação prevista e a mascara

# %%
from keras import backend as K

##Metrica
def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  
    return iou
##Loss Function
def iou_coef_loss(y_true, y_pred):
    return -iou_coef(y_true, y_pred)

# %% [markdown]
# source: https://towardsdatascience.com/metrics-to-evaluate-your-semantic-segmentation-model-6bcb99639aa2

# %% [markdown]
# ### Formando os arrays de imagens e mascaras

# %%
directory = os.fsencode("./new_maps")

images = []
titulos = []

list_directory = os.listdir(directory.decode("utf-8"))

list_directory.sort()
    
for file in list_directory:
    filename = os.fsdecode(file)
    titulos.append(filename)
    filename_path = directory.decode("utf-8") + "/" + filename
    img = imageio.imread(filename_path)
    images.append(img)
    
directory = os.fsencode("./new_masks")

masks = []
titulos = []

list_directory = os.listdir(directory.decode("utf-8"))

list_directory.sort()
    
for file in list_directory:
    filename = os.fsdecode(file)
    titulos.append(filename)
    filename_path = directory.decode("utf-8") + "/" + filename
    img = imageio.imread(filename_path)
    masks.append(img)
    
masks = np.array(masks)
images = np.array(images)

masks = np.expand_dims(masks, -1)

# %% [markdown]
# ### Splitando os dados entre treino e teste

# %%
from sklearn.model_selection import train_test_split
train_images, test_images, train_masks, test_masks = train_test_split(images, masks, test_size=0.2)

# %% [markdown]
# ### Criando o modelo

# %%
from keras.models import Model, load_model
import tensorflow as tf
from keras.layers import Input
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
import keras

# %%
inputs = Input((256, 256, 3))

conv1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (inputs)
conv1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv1)
pooling1 = MaxPooling2D((2, 2)) (conv1)

conv2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling1)
conv2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv2)
pooling2 = MaxPooling2D((2, 2)) (conv2)

conv3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling2)
conv3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv3)
pooling3 = MaxPooling2D((2, 2)) (conv3)

conv4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling3)
conv4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv4)
pooling4 = MaxPooling2D(pool_size=(2, 2)) (conv4)

conv5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling4)
conv5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv5)

upsample6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (conv5)
upsample6 = concatenate([upsample6, conv4])
conv6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample6)
conv6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv6)

upsample7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (conv6)
upsample7 = concatenate([upsample7, conv3])
conv7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample7)
conv7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv7)

upsample8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (conv7)
upsample8 = concatenate([upsample8, conv2])
conv8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample8)
conv8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv8)

upsample9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (conv8)
upsample9 = concatenate([upsample9, conv1], axis=3)
conv9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample9)
conv9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (conv9)

model = Model(inputs=[inputs], outputs=[outputs])

# %%
model.compile(
      optimizer='adam',
      loss=iou_coef_loss,
      metrics=[iou_coef])

history = model.fit(train_images,
                    train_masks/255,
                    validation_split = 0.1,
                    epochs=40)
# Out:
# Train on 25 samples, validate on 3 samples
# Epoch 1/40
# 25/25 [==============================] - 12s 477ms/step - loss: -0.0317 - iou_coef: 0.0317 - val_loss: -0.1055 - val_iou_coef: 0.1055
# Epoch 2/40
# 25/25 [==============================] - 10s 383ms/step - loss: -0.0529 - iou_coef: 0.0529 - val_loss: -0.1166 - val_iou_coef: 0.1166
# Epoch 3/40
# 25/25 [==============================] - 10s 390ms/step - loss: -0.0561 - iou_coef: 0.0561 - val_loss: -0.1194 - val_iou_coef: 0.1194
# Epoch 4/40
# 25/25 [==============================] - 10s 390ms/step - loss: -0.0582 - iou_coef: 0.0582 - val_loss: -0.0968 - val_iou_coef: 0.0968
# Epoch 5/40
# 25/25 [==============================] - 10s 385ms/step - loss: -0.0553 - iou_coef: 0.0553 - val_loss: -0.1234 - val_iou_coef: 0.1234
# Epoch 6/40
# 25/25 [==============================] - 10s 391ms/step - loss: -0.0625 - iou_coef: 0.0625 - val_loss: -0.1208 - val_iou_coef: 0.1208
# Epoch 7/40
# 25/25 [==============================] - 10s 386ms/step - loss: -0.0583 - iou_coef: 0.0583 - val_loss: -0.1338 - val_iou_coef: 0.1338
# Epoch 8/40
# 25/25 [==============================] - 10s 385ms/step - loss: -0.0702 - iou_coef: 0.0702 - val_loss: -0.0641 - val_iou_coef: 0.0641
# Epoch 9/40
# 25/25 [==============================] - 10s 385ms/step - loss: -0.0506 - iou_coef: 0.0506 - val_loss: -0.1244 - val_iou_coef: 0.1244
# Epoch 10/40
# 25/25 [==============================] - 10s 382ms/step - loss: -0.0598 - iou_coef: 0.0598 - val_loss: -0.1123 - val_iou_coef: 0.1123
# Epoch 11/40
# 25/25 [==============================] - 10s 387ms/step - loss: -0.0541 - iou_coef: 0.0541 - val_loss: -0.1107 - val_iou_coef: 0.1107
# Epoch 12/40
# 25/25 [==============================] - 10s 387ms/step - loss: -0.0531 - iou_coef: 0.0531 - val_loss: -0.1104 - val_iou_coef: 0.1104
# Epoch 13/40
# 25/25 [==============================] - 10s 385ms/step - loss: -0.0529 - iou_coef: 0.0529 - val_loss: -0.1106 - val_iou_coef: 0.1106
# Epoch 14/40
# 25/25 [==============================] - 10s 386ms/step - loss: -0.0531 - iou_coef: 0.0531 - val_loss: -0.1118 - val_iou_coef: 0.1118
# Epoch 15/40
# 25/25 [==============================] - 10s 414ms/step - loss: -0.0538 - iou_coef: 0.0538 - val_loss: -0.1181 - val_iou_coef: 0.1181
# Epoch 16/40
# 25/25 [==============================] - 10s 387ms/step - loss: -0.0569 - iou_coef: 0.0569 - val_loss: -0.1428 - val_iou_coef: 0.1428
# Epoch 17/40
# 25/25 [==============================] - 10s 388ms/step - loss: -0.0730 - iou_coef: 0.0730 - val_loss: -0.0761 - val_iou_coef: 0.0761
# Epoch 18/40
# 25/25 [==============================] - 10s 391ms/step - loss: -0.0521 - iou_coef: 0.0521 - val_loss: -0.1106 - val_iou_coef: 0.1106
# Epoch 19/40
# 25/25 [==============================] - 10s 391ms/step - loss: -0.0681 - iou_coef: 0.0681 - val_loss: -0.1441 - val_iou_coef: 0.1441
# Epoch 20/40
# 25/25 [==============================] - 10s 382ms/step - loss: -0.0707 - iou_coef: 0.0707 - val_loss: -0.1491 - val_iou_coef: 0.1491
# Epoch 21/40
# 25/25 [==============================] - 10s 389ms/step - loss: -0.0730 - iou_coef: 0.0730 - val_loss: -0.1374 - val_iou_coef: 0.1374
# Epoch 22/40
# 25/25 [==============================] - 10s 391ms/step - loss: -0.0822 - iou_coef: 0.0822 - val_loss: -0.1511 - val_iou_coef: 0.1511
# Epoch 23/40
# 25/25 [==============================] - 10s 387ms/step - loss: -0.0891 - iou_coef: 0.0891 - val_loss: -0.1803 - val_iou_coef: 0.1803
# Epoch 24/40
# 25/25 [==============================] - 10s 392ms/step - loss: -0.0916 - iou_coef: 0.0916 - val_loss: -0.1607 - val_iou_coef: 0.1607
# Epoch 25/40
# 25/25 [==============================] - 10s 391ms/step - loss: -0.1058 - iou_coef: 0.1058 - val_loss: -0.2061 - val_iou_coef: 0.2061
# Epoch 26/40
# 25/25 [==============================] - 10s 393ms/step - loss: -0.1068 - iou_coef: 0.1068 - val_loss: -0.0356 - val_iou_coef: 0.0356
# Epoch 27/40
# 25/25 [==============================] - 10s 397ms/step - loss: -0.0506 - iou_coef: 0.0506 - val_loss: -0.1922 - val_iou_coef: 0.1922
# Epoch 28/40
# 25/25 [==============================] - 10s 391ms/step - loss: -0.0915 - iou_coef: 0.0915 - val_loss: -0.1542 - val_iou_coef: 0.1542
# Epoch 29/40
# 25/25 [==============================] - 10s 389ms/step - loss: -0.0728 - iou_coef: 0.0728 - val_loss: -0.1458 - val_iou_coef: 0.1458
# Epoch 30/40
# 25/25 [==============================] - 10s 393ms/step - loss: -0.0693 - iou_coef: 0.0693 - val_loss: -0.1511 - val_iou_coef: 0.1511
# Epoch 31/40
# 25/25 [==============================] - 10s 387ms/step - loss: -0.0717 - iou_coef: 0.0717 - val_loss: -0.1735 - val_iou_coef: 0.1735
# Epoch 32/40
# 25/25 [==============================] - 10s 390ms/step - loss: -0.0824 - iou_coef: 0.0824 - val_loss: -0.2192 - val_iou_coef: 0.2192
# Epoch 33/40
# 25/25 [==============================] - 10s 392ms/step - loss: -0.1152 - iou_coef: 0.1152 - val_loss: -0.0319 - val_iou_coef: 0.0319
# Epoch 34/40
# 25/25 [==============================] - 10s 390ms/step - loss: -0.0421 - iou_coef: 0.0421 - val_loss: -0.0990 - val_iou_coef: 0.0990
# Epoch 35/40
# 25/25 [==============================] - 10s 390ms/step - loss: -0.0819 - iou_coef: 0.0819 - val_loss: -0.2234 - val_iou_coef: 0.2234
# Epoch 36/40
# 25/25 [==============================] - 10s 413ms/step - loss: -0.1131 - iou_coef: 0.1131 - val_loss: -0.1924 - val_iou_coef: 0.1924
# Epoch 37/40
# 25/25 [==============================] - 10s 392ms/step - loss: -0.0917 - iou_coef: 0.0917 - val_loss: -0.1958 - val_iou_coef: 0.1958
# Epoch 38/40
# 25/25 [==============================] - 10s 391ms/step - loss: -0.0936 - iou_coef: 0.0936 - val_loss: -0.2343 - val_iou_coef: 0.2343
# Epoch 39/40
# 25/25 [==============================] - 10s 392ms/step - loss: -0.1172 - iou_coef: 0.1172 - val_loss: -0.1895 - val_iou_coef: 0.1895
# Epoch 40/40
# 25/25 [==============================] - 10s 411ms/step - loss: -0.1177 - iou_coef: 0.1177 - val_loss: -0.1756 - val_iou_coef: 0.1756

# %%
model.evaluate(test_images, test_masks)
# Out:
# 8/8 [==============================] - 1s 105ms/step
# [-0.1877981722354889, 0.1877981722354889]

# %%
predictions = model.predict(test_images, verbose=1)
# Out:
# 8/8 [==============================] - 1s 104ms/step

# %%
f = plt.figure()

for i in range(0,6,3):

    f.add_subplot(2, 3, i+1)
    plt.imshow(test_images[i][:,:,0])
    plt.title("Map")
    plt.axis('off')

    f.add_subplot(2, 3, i+2)
    plt.imshow(np.squeeze(test_masks[i][:,:,0]))
    plt.title("Mask")
    plt.axis('off')

    f.add_subplot(2, 3, i+3)
    plt.imshow(np.squeeze(predictions[i][:,:,0]))
    plt.title("Prediction")
    plt.axis('off')


plt.show()

# %% [markdown]
# ### Observacoes:

# %% [markdown]
# #### Devido ao dataset extremamente reduzido (somente 36 imagens para elaborar um esboco do projeto) e a arquitetura nada otimizada da CNN, os outputs gerados pelo modelo tem um resultado muito abaixo do esperado,
